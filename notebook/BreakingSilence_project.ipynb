# %% [markdown]
# <a href="https://colab.research.google.com/github/DeborAguiar/BreakingSilence/blob/main/notebook/BreakingSilence_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center>Violence Against Women and Girls</center></h1>
#
# <center><img src="https://equineteurope.org/wp-content/uploads/2019/11/stop-violence-against-women.jpg" width="800"></img></center>
#
#
#
# # Content
#
# - <a href='#1'>Introduction</a>
# - <a href='#2'>Analysis preparation</a>
# - <a href='#3'>What demographics are telling us</a>
# - <a href='#4'>What the question answered reveals</a>
# - <a href='#5'>Demographics and question answered combined</a>
# - <a href='#6'>Median violence percent per country</a>
# - <a href='#7'>Maxim violence percent per country</a>
# - <a href='#8'>Summary of findings</a>

# %% [markdown]
# # <a id='1'>Introduction</a>
#
# We will analyze the data on violence on women and girls. The data is collected from 70 countries and contains demographics questions and answers as well as percent of response to 5 violence specific questions.

# %% [markdown]
# # <a id='2'>Analysis preparation</a>
#
# We input the data, we glimpse the data, we look to missing data and we look to number of categories for each type of categorical data.
#
# ## Data input

# %%
import pandas as pd
data_df = pd.read_csv("https://github.com/DeborAguiar/BreakingSilence/blob/main/data/violence_data.csv?raw=true",
                               encoding='utf8', sep=",")

# %% [markdown]
# ## Glimpse the data

# %%
data_df.head()
# Out:
#    RecordID      Country Gender Demographics Question  \
# 0         1  Afghanistan      F        Marital status
# 1         1  Afghanistan      F             Education
# 2         1  Afghanistan      F             Education
# 3         1  Afghanistan      F             Education
# 4         1  Afghanistan      F        Marital status
#
#           Demographics Response                   Question Survey Year  Value
# 0                 Never married  ... if she burns the food  01/01/2015    NaN
# 1                        Higher  ... if she burns the food  01/01/2015   10.1
# 2                     Secondary  ... if she burns the food  01/01/2015   13.7
# 3                       Primary  ... if she burns the food  01/01/2015   13.8
# 4  Widowed, divorced, separated  ... if she burns the food  01/01/2015   13.8

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RecordID               12600 non-null  int64
#  1   Country                12600 non-null  object
#  2   Gender                 12600 non-null  object
#  3   Demographics Question  12600 non-null  object
#  4   Demographics Response  12600 non-null  object
#  5   Question               12600 non-null  object
#  6   Survey Year            12600 non-null  object
#  7   Value                  11187 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 787.6+ KB

# %%
columns = data_df.columns
for column in columns:
    print(f"{column} : {data_df[column].nunique()}")
# Out:
# RecordID : 420
# Country : 70
# Gender : 2
# Demographics Question : 5
# Demographics Response : 15
# Question : 6
# Survey Year : 18
# Value : 757

# %% [markdown]
# # <a id='3'>What demographics are telling us</a>
#
#
# Let's look first to what demographics are telling to us. There are 5 demographics questions:
# * Age (15-24, 25-34, 35-49)
# * Education (No Education, Primary, Secondary, Higher)
# * Employement (Unemployed, Employed for cash, Employed for kind)
# * Marital status (Maried or living together, Widowed, divorced, separated, Never Married)
# * Residence (Rural, Urban)
#
# We will aggregate the data on the demographic question, answer and calculate the minimm, maximum, median and average stats per each of this demographic.

# %%
demographics_df = data_df.groupby(["Demographics Question", "Demographics Response"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
demographics_df.columns = ["Question", "Response", "Median", "Max", "Min", "Mean"]
print("Violence % median, min, max, and mean per demographic group")
demographics_df.sort_values(["Question", "Median"])
# Out:
# Violence % median, min, max, and mean per demographic group
#           Question                      Response  Median   Max  Min       Mean
# 2              Age                         35-49   14.15  81.0  0.2  19.336412
# 1              Age                         25-34   14.45  81.5  0.1  19.703562
# 0              Age                         15-24   17.50  80.1  0.1  21.084169
# 3        Education                        Higher    4.20  74.6  0.0   8.898670
# 6        Education                     Secondary   13.05  76.7  0.2  17.378892
# 5        Education                       Primary   18.40  80.5  0.1  22.819093
# 4        Education                  No education   21.55  82.0  0.0  25.403125
# 9       Employment                    Unemployed   14.55  80.1  0.0  19.539710
# 7       Employment             Employed for cash   14.85  81.5  0.1  19.553804
# 8       Employment             Employed for kind   20.15  86.9  0.3  24.445541
# 10  Marital status    Married or living together   14.80  82.1  0.2  20.181003
# 11  Marital status                 Never married   14.90  72.1  0.0  18.704360
# 12  Marital status  Widowed, divorced, separated   17.15  75.9  0.0  20.683511
# 14       Residence                         Urban   11.05  74.4  0.1  15.895778
# 13       Residence                         Rural   19.00  82.1  0.2  23.294063

# %% [markdown]
# The data grouped on demographics shows the following:
# * The most exposed age group is the 15-24, with a median of 17.50 and max of 80.1, while the absolute max is for 25-34 age group;
# * Education level of girls and women is a very good predictor for violence against them: a higher education level will ensure a small median percent of 4.2%, while No education shows a 21.55% median and a 82% maximum violence percent.
# * Employment factor also counts, from Unemployed to Employed for kind the median is varying from 14.55% to 20.15%. The women that work tend to be more exposed to violence.
# * Marriage is slighly protecting if we look to the median, but married women are more exposed to higher level of violence. Widowed, divorced or separated have a smaller median than Married or living together group, as well as the max. But it might be also an age factor here.
# * Women from Urban areas are less exposed to violence than women from Rural areas, both the median and the max values being smaller in Urban vs. Rural areas.

# %% [markdown]
# # <a id='4'>What the question answered reveals</a>

# %%
question_df = data_df.groupby(["Question"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
question_df.columns = ["Question", "Median", "Max", "Min", "Mean"]
print("Violence % median, min, max, and mean per question asked")
question_df.sort_values(["Median"])
# Out:
# Violence % median, min, max, and mean per question asked
#                                   Question  Median   Max  Min       Mean
# 2                ... if she burns the food     6.4  56.7  0.0   9.203445
# 5  ... if she refuses to have sex with him     9.0  68.7  0.0  13.209613
# 1               ... if she argues with him    15.7  76.5  0.0  18.983652
# 3  ... if she goes out without telling him    16.4  77.0  0.0  20.046321
# 4         ... if she neglects the children    20.8  75.6  0.0  23.461249
# 0     ... for at least one specific reason    31.0  86.9  0.0  33.217152

# %% [markdown]
# Generally, the median and maximum are aligned. The reasons for violence, ranged by median values are:
# * if she burns the food;
# * if she refuses to have sex with him;
# * if she argues with him;
# * if she goes out without telling him;
# * if she neglects the children.
#
# Non specified but at least one specific reason would have the maximum median value and the absolute maximum percent.

# %% [markdown]
# # <a id='5'>Demographics and question answered combined</a>

# %%
demoq_df = data_df.groupby(["Demographics Question", "Demographics Response", "Question"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
demoq_df.columns = ["Demographics Question", "Demographics Response", "Question", "Median", "Max", "Min", "Mean"]
print("Violence % median, min, max, and mean per demographic group and question asked")
demoq_df = demoq_df.sort_values(["Demographics Question", "Demographics Response", "Median"])
demoq_df.head()
# Out:
# Violence % median, min, max, and mean per demographic group and question asked
#   Demographics Question Demographics Response  \
# 2                   Age                 15-24
# 5                   Age                 15-24
# 3                   Age                 15-24
# 1                   Age                 15-24
# 4                   Age                 15-24
#
#                                   Question  Median   Max  Min       Mean
# 2                ... if she burns the food    8.50  47.7  0.1  10.098387
# 5  ... if she refuses to have sex with him   10.05  59.4  0.3  13.404762
# 3  ... if she goes out without telling him   18.40  67.7  0.2  21.026563
# 1               ... if she argues with him   18.65  65.5  0.5  20.304032
# 4         ... if she neglects the children   23.20  61.4  1.9  25.306250

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def show_answers_per_demographic_question(question, aggregate="Median", layout_mode="Single"):
    font_size = 8
    title_font_size = 12
    if layout_mode == "Single":
        fig = go.Figure()
        font_size = 10
    else:
        fig = make_subplots(rows=2, cols=2, specs=[[{'type': 'polar'}]*2]*2)

    sel_df = demoq_df.loc[demoq_df["Demographics Question"]==question]
    answers = list(sel_df["Demographics Response"].unique())
    count = 0
    for answer in answers:
        subsel_df = sel_df.loc[sel_df["Demographics Response"] == answer]
        if layout_mode == "Single":
            fig.add_trace(go.Scatterpolar(name=answer, r=subsel_df[aggregate], theta=subsel_df['Question']))
        else:
            fig.add_trace(go.Scatterpolar(name=answer, r=subsel_df[aggregate], theta=subsel_df['Question']), count%2 + 1, int(count/2+1))
        count = count + 1
    fig.update_traces(fill='toself')
    fig.update_polars(bgcolor='white')
    fig.update_polars(angularaxis_linecolor='darkgrey')
    fig.update_polars(angularaxis_gridcolor='darkgrey')
    fig.update_polars(radialaxis_gridcolor='darkgrey')
    fig.update_polars(radialaxis_linecolor='darkgrey')
    fig.update_layout(title='Demografics Question: '+ question + ' | Statistics: ' + aggregate,font=dict(family="Courier New, monospace",size=title_font_size))
    fig.show()

# %%
show_answers_per_demographic_question("Age")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ae619d26-a829-47bd-8bf2-da188f63e1a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae619d26-a829-47bd-8bf2-da188f63e1a2")) {                    Plotly.newPlot(                        "ae619d26-a829-47bd-8bf2-da188f63e1a2",                        [{"name":"15-24","r":[8.5,10.05,18.4,18.65,23.200000000000003,36.0],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"25-34","r":[6.3,9.25,15.3,15.6,19.25,30.75],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"35-49","r":[5.2,9.2,14.0,16.25,19.25,29.049999999999997],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"ty ...

# %%
show_answers_per_demographic_question("Age", aggregate="Max")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f61a8d4b-18fd-473b-9496-ddf9390878f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f61a8d4b-18fd-473b-9496-ddf9390878f9")) {                    Plotly.newPlot(                        "f61a8d4b-18fd-473b-9496-ddf9390878f9",                        [{"name":"15-24","r":[47.7,59.4,67.7,65.5,61.4,80.1],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"25-34","r":[50.5,64.5,68.5,70.8,65.5,81.5],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"35-49","r":[47.4,65.5,69.8,65.1,62.0,81.0],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outl ...

# %%
show_answers_per_demographic_question("Education")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a8ff07c2-171a-4291-a911-4aeb12ff7520" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8ff07c2-171a-4291-a911-4aeb12ff7520")) {                    Plotly.newPlot(                        "a8ff07c2-171a-4291-a911-4aeb12ff7520",                        [{"name":"Higher","r":[1.1,2.0,3.7,4.3,8.1,13.4],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"No education","r":[10.5,13.8,21.3,22.5,26.1,37.3],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Primary","r":[8.2,11.7,20.0,20.0,24.1,38.1],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Secondary","r":[5.3,6.75,13.95,14.25,18.95,29.85],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[ ...

# %%
show_answers_per_demographic_question("Education", aggregate="Max")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e8727e28-eb80-4c96-9e7e-bdbd27dc23ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8727e28-eb80-4c96-9e7e-bdbd27dc23ea")) {                    Plotly.newPlot(                        "e8727e28-eb80-4c96-9e7e-bdbd27dc23ea",                        [{"name":"Higher","r":[24.4,37.9,58.3,63.8,63.6,74.6],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"No education","r":[49.3,66.7,69.6,71.0,66.5,82.0],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Primary","r":[56.2,65.4,69.5,66.5,66.3,80.5],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Secondary","r":[51.9,51.0,61.8,62.5,64.0,76.7],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale ...

# %%
show_answers_per_demographic_question("Employment")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="268983f5-c6ca-4533-92ed-dddc627196f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("268983f5-c6ca-4533-92ed-dddc627196f5")) {                    Plotly.newPlot(                        "268983f5-c6ca-4533-92ed-dddc627196f5",                        [{"name":"Employed for cash","r":[6.0,9.149999999999999,15.25,15.6,19.1,29.3],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Employed for kind","r":[8.8,11.9,20.6,21.4,25.7,38.5],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Unemployed","r":[6.75,8.75,15.3,15.5,21.5,31.950000000000003],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f ...

# %%
show_answers_per_demographic_question("Employment", aggregate="Max")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c1291d00-8255-4030-9ae3-812071a70fcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1291d00-8255-4030-9ae3-812071a70fcb")) {                    Plotly.newPlot(                        "c1291d00-8255-4030-9ae3-812071a70fcb",                        [{"name":"Employed for cash","r":[56.7,64.9,69.6,66.7,67.0,81.5],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Employed for kind","r":[49.4,68.7,77.0,76.5,75.6,86.9],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Unemployed","r":[42.3,59.3,67.0,66.6,59.6,80.1],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"typ ...

# %%
show_answers_per_demographic_question("Marital status")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b661aa79-2bbf-4c9a-bc0f-051a0894a932" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b661aa79-2bbf-4c9a-bc0f-051a0894a932")) {                    Plotly.newPlot(                        "b661aa79-2bbf-4c9a-bc0f-051a0894a932",                        [{"name":"Married or living together","r":[5.85,9.6,15.6,15.75,20.6,30.450000000000003],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Never married","r":[7.65,8.6,16.200000000000003,16.9,21.75,33.349999999999994],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Widowed, divorced, separated","r":[6.8,10.4,18.5,20.0,23.4,33.2],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[ ...

# %%
show_answers_per_demographic_question("Marital status", aggregate="Max")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="05f4b6e4-f21a-4d3c-91bf-6040797364a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05f4b6e4-f21a-4d3c-91bf-6040797364a4")) {                    Plotly.newPlot(                        "05f4b6e4-f21a-4d3c-91bf-6040797364a4",                        [{"name":"Married or living together","r":[50.5,66.1,71.0,67.6,65.5,82.1],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Never married","r":[40.9,48.0,57.7,59.2,58.6,72.1],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Widowed, divorced, separated","r":[45.9,52.2,59.8,65.5,59.9,75.9],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f9 ...

# %%
show_answers_per_demographic_question("Residence")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="17244f6a-66e1-475a-a675-d535cee37a02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17244f6a-66e1-475a-a675-d535cee37a02")) {                    Plotly.newPlot(                        "17244f6a-66e1-475a-a675-d535cee37a02",                        [{"name":"Rural","r":[8.4,11.6,19.9,21.0,24.549999999999997,37.3],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Urban","r":[4.2,6.65,10.7,12.7,15.75,25.0],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"b ...

# %%
show_answers_per_demographic_question("Residence", aggregate="Max")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a0448b3f-e66e-4e85-b2b0-bf65a23f949d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0448b3f-e66e-4e85-b2b0-bf65a23f949d")) {                    Plotly.newPlot(                        "a0448b3f-e66e-4e85-b2b0-bf65a23f949d",                        [{"name":"Rural","r":[49.4,65.8,72.4,70.6,70.0,82.1],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she goes out without telling him","... if she argues with him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"},{"name":"Urban","r":[45.9,54.6,62.6,60.7,61.0,74.4],"theta":["... if she burns the food","... if she refuses to have sex with him","... if she argues with him","... if she goes out without telling him","... if she neglects the children","... for at least one specific reason"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_ ...

# %% [markdown]
# # <a id='6'>Median violence percent per country</a>

# %%
country_df = pd.read_csv("https://github.com/DeborAguiar/BreakingSilence/blob/main/data/wikipedia-iso-country-codes.csv?raw=true", encoding='utf8', sep=",")
country_df.columns = ["Country", "A2C", "A3C", "Num","ISO"]
datac_df = data_df.merge(country_df)

# %%
df = datac_df.groupby(["Country", "A3C"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
df.columns = ["Country", "A3C", "Median", "Max", "Min", "Mean"]

# %%
def show_on_map(df, aggregate, title):
    fig = go.Figure(data=go.Choropleth(
        locations = df['A3C'],
        z = df[aggregate],
        text = df['Country'],
        colorscale = 'Rainbow',
        autocolorscale=False,
        reversescale=False,
        marker_line_color='darkgray',
        marker_line_width=0.5,
        colorbar_tickprefix = '%',
        colorbar_title = 'Violence %',
    ))

    fig.update_layout(
        title_text=title,
        geo=dict(
            showframe=False,
            showcoastlines=False,
            projection_type='equirectangular'
        ),
        annotations = [dict(
            x=0.55,
            y=0.1,
            xref='paper',
            yref='paper',
            text='Source: <a href="https://www.kaggle.com/andrewmvd/violence-against-women-and-girls">\
                Violence against Women and Girls</a>',
            showarrow = False
        )]
    )

    fig.show()

# %%
show_on_map(df, "Median", "Violence against Women and Girls - Country median level of violence[%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3fdd2e37-1160-4070-8bb3-7e09e9a8169d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fdd2e37-1160-4070-8bb3-7e09e9a8169d")) {                    Plotly.newPlot(                        "3fdd2e37-1160-4070-8bb3-7e09e9a8169d",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[44.5,3.75,11.8,6.949999999999999,33.95,14.649999999999999,12.649999999999999,5.35,19.65,25.85,15.6,20.799999999999997,41.85,1.6,12.850000000000001,1.05,20.55,48.7,23.5,19.15,23.6,9.7,3.2,41.8,6.8,4.95,4.5,21.200000000000003,9.8,12.1,20.5,16.5,16.45,10.95,6.3,10.45,36.3,48.9,6.6,15.350000000000001,11.850000000000001,9.65,5.4,25.65,16.75,25.45,1.25,2.8,12.7,10.05,21.95,24.6,2.7,46.05,29.3,44.65,12.05,5.25,36.3,23.6,2.3499999999999996,28.2,23.9,16.6],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"], ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="No education"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["median"]).reset_index()
df.columns = ["Country", "A3C", "Median"]
show_on_map(df, "Median", "Violence against Women with No education - Country Median level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="76808235-33dc-4922-8503-cbb5ff42c25b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76808235-33dc-4922-8503-cbb5ff42c25b")) {                    Plotly.newPlot(                        "76808235-33dc-4922-8503-cbb5ff42c25b",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[49.55,15.100000000000001,19.1,null,59.95,17.2,16.5,10.65,22.6,30.549999999999997,22.65,25.85,43.45,3.9000000000000004,16.700000000000003,3.05,36.0,56.75,40.0,24.75,27.200000000000003,19.6,5.4,51.05,9.600000000000001,6.15,11.100000000000001,26.450000000000003,11.600000000000001,19.049999999999997,41.849999999999994,29.200000000000003,19.95,14.25,6.8,8.3,46.0,65.69999999999999,10.1,16.9,18.85,14.649999999999999,11.25,30.4,23.25,38.5,2.2,6.25,18.0,12.75,32.05,29.95,3.3499999999999996,58.05,34.9,41.35,19.75,17.799999999999997,46.2,26.450000000000003,null,39.8,31.099999999999998,29.5],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0, ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="Higher"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["median"]).reset_index()
df.columns = ["Country", "A3C", "Median"]
show_on_map(df, "Median", "Violence against Women with Higher education - Country Median level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="af523f18-793f-44f0-a034-3b56c83d90f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af523f18-793f-44f0-a034-3b56c83d90f6")) {                    Plotly.newPlot(                        "af523f18-793f-44f0-a034-3b56c83d90f6",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[32.4,0.9500000000000001,2.15,4.7,14.3,6.75,1.5499999999999998,1.7999999999999998,3.25,2.75,2.2,5.25,26.0,0.8500000000000001,6.75,0.2,6.25,9.55,6.95,8.6,9.25,1.65,0.35,24.6,1.65,0.6,0.4,15.4,6.75,8.55,6.8,2.45,9.0,5.0,1.25,7.4,12.55,9.600000000000001,1.0,7.2,3.0,3.0,0.7,4.25,7.15,8.85,0.75,1.2000000000000002,3.5,9.05,3.0,11.55,0.7,36.400000000000006,2.4,58.15,4.05,1.0,17.85,9.65,1.9,10.3,4.8,4.1],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"# ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="Rural"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["median"]).reset_index()
df.columns = ["Country", "A3C", "Median"]
show_on_map(df, "Median", "Violence against Women in Rural Areas - Country Median level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="55880648-1aad-4c27-99c5-532730d5393a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55880648-1aad-4c27-99c5-532730d5393a")) {                    Plotly.newPlot(                        "55880648-1aad-4c27-99c5-532730d5393a",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[47.95,4.45,20.15,11.8,44.65,15.45,15.15,8.4,22.950000000000003,29.65,17.75,27.55,46.0,2.1500000000000004,16.75,1.2,27.6,57.3,35.5,27.65,32.2,14.149999999999999,4.75,49.95,8.25,5.800000000000001,6.6,21.799999999999997,12.55,15.700000000000001,23.5,22.15,19.15,14.15,7.2,12.75,48.25,70.25,7.85,15.799999999999999,15.75,10.75,8.9,33.0,21.95,34.75,1.9,3.35,15.9,10.55,34.25,28.799999999999997,4.7,53.7,34.0,38.349999999999994,15.45,10.95,43.05,27.2,3.35,36.6,34.8,20.25],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444 ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="Urban"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["median"]).reset_index()
df.columns = ["Country", "A3C", "Median"]
show_on_map(df, "Median", "Violence against Women in Urban Areas - Country Median level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a056080b-c7d0-4fa2-a1a4-35c6488b4d29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a056080b-c7d0-4fa2-a1a4-35c6488b4d29")) {                    Plotly.newPlot(                        "a056080b-c7d0-4fa2-a1a4-35c6488b4d29",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[43.2,2.95,9.05,4.4,25.6,12.649999999999999,10.7,4.15,13.2,18.45,7.4,15.55,40.25,1.15,9.25,0.9,11.6,36.75,15.25,18.2,16.5,6.5,1.75,38.8,2.8499999999999996,4.7,2.7,17.8,8.649999999999999,9.7,15.0,12.85,14.350000000000001,12.45,3.75,11.0,27.450000000000003,35.25,5.9,12.95,8.05,8.85,3.0,21.25,10.7,15.3,0.8500000000000001,2.15,11.1,8.5,16.049999999999997,18.45,1.9000000000000001,41.35,24.8,57.55,6.6,3.95,30.05,17.700000000000003,2.1,20.5,17.2,11.25],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0. ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="15-24"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["median"]).reset_index()
df.columns = ["Country", "A3C", "Median"]
show_on_map(df, "Median", "Violence against Women age 15-24 - Country Median level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8d44021c-1a56-4c62-be6b-633e6d116e63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d44021c-1a56-4c62-be6b-633e6d116e63")) {                    Plotly.newPlot(                        "8d44021c-1a56-4c62-be6b-633e6d116e63",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[45.45,3.25,13.05,6.1,33.9,14.25,12.3,5.15,21.25,31.65,13.95,21.25,43.05,1.65,16.6,1.45,24.1,46.55,30.25,20.2,25.549999999999997,11.9,3.8,42.8,6.95,6.85,4.85,21.549999999999997,11.350000000000001,13.8,20.799999999999997,21.6,19.6,15.3,8.3,14.85,46.849999999999994,49.0,7.25,16.4,11.75,10.05,4.25,34.5,16.9,30.0,1.15,2.8,18.65,9.899999999999999,28.799999999999997,22.950000000000003,2.95,43.25,34.2,43.4,11.85,4.05,33.9,28.35,1.7999999999999998,28.9,25.1,22.35],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#b ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="25-34"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["median"]).reset_index()
df.columns = ["Country", "A3C", "Median"]
show_on_map(df, "Median", "Violence against Women age 25-34 - Country Median level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7c44adac-a987-4186-95ea-d3600e755930" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c44adac-a987-4186-95ea-d3600e755930")) {                    Plotly.newPlot(                        "7c44adac-a987-4186-95ea-d3600e755930",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[47.400000000000006,3.6,11.149999999999999,7.65,35.599999999999994,14.2,13.15,5.1,19.5,26.55,14.95,20.15,46.9,1.15,12.85,1.05,20.25,49.25,30.45,18.9,20.6,8.899999999999999,2.6,46.65,6.4,4.1,3.9,19.75,10.649999999999999,10.4,20.5,16.1,16.8,13.899999999999999,5.1,11.149999999999999,40.4,49.099999999999994,6.55,13.45,11.45,8.35,6.05,31.0,17.35,27.25,0.8500000000000001,2.7,12.95,10.0,21.700000000000003,27.299999999999997,2.6500000000000004,56.75,28.200000000000003,48.3,11.65,4.5,38.1,21.6,2.5,31.75,26.35,14.95],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="35-49"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["median"]).reset_index()
df.columns = ["Country", "A3C", "Median"]
show_on_map(df, "Median", "Violence against Women age 35-49 - Country Median level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d58093ae-6bb9-42bd-ad36-ee9221d62a70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d58093ae-6bb9-42bd-ad36-ee9221d62a70")) {                    Plotly.newPlot(                        "d58093ae-6bb9-42bd-ad36-ee9221d62a70",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[47.35,4.5,12.5,7.95,33.55,15.5,13.65,6.5,20.9,23.35,20.3,21.65,44.5,1.4,9.2,0.7,22.9,52.650000000000006,33.4,19.0,18.85,7.65,3.2,46.95,6.65,4.35,4.4,20.200000000000003,9.399999999999999,8.1,21.0,17.6,12.45,12.45,5.4,10.25,40.05,50.25,5.95,15.100000000000001,11.05,9.05,5.75,27.05,16.1,25.700000000000003,1.2000000000000002,2.85,10.75,9.05,20.7,25.65,2.05,52.95,29.35,45.349999999999994,11.8,6.85,39.8,20.4,2.85,34.8,24.65,12.2],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8 ...

# %% [markdown]
# # <a id='7'>Maximum violence percent per country</a>

# %%
df = datac_df.groupby(["Country", "A3C"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
df.columns = ["Country", "A3C", "Median", "Max", "Min", "Mean"]
show_on_map(df, "Max", "Violence against Women and Girls - Country maximum level of violence[%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="150ff22b-f2f8-4eac-b66c-9c7173346e4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("150ff22b-f2f8-4eac-b66c-9c7173346e4c")) {                    Plotly.newPlot(                        "150ff22b-f2f8-4eac-b66c-9c7173346e4c",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[86.9,29.7,37.4,47.0,74.3,33.0,37.3,23.4,47.6,69.1,58.0,53.9,79.6,13.2,49.7,10.4,62.3,82.8,71.9,60.9,72.7,47.1,18.3,71.2,34.0,22.5,23.6,52.4,42.2,44.3,60.4,52.5,48.5,36.9,20.0,27.6,83.3,86.1,26.2,61.3,43.5,38.8,22.6,63.2,50.2,62.6,6.9,17.5,46.1,35.8,59.7,70.9,14.9,70.1,68.3,85.2,38.4,37.0,72.6,59.8,22.0,61.6,63.7,55.2],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="No education"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["max"]).reset_index()
df.columns = ["Country", "A3C", "Max"]
show_on_map(df, "Max", "Violence against Women with No education - Country Max level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4fb38360-487f-4e70-bf3f-5812d008b7af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fb38360-487f-4e70-bf3f-5812d008b7af")) {                    Plotly.newPlot(                        "4fb38360-487f-4e70-bf3f-5812d008b7af",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[81.0,26.6,34.5,null,74.3,33.0,37.3,23.4,47.5,65.9,57.6,49.6,70.9,13.2,39.7,10.4,53.1,77.5,71.9,58.7,67.8,47.1,18.3,70.9,34.0,22.5,23.6,51.6,26.6,36.3,60.4,52.5,45.8,30.5,18.2,19.4,82.0,78.5,26.2,52.1,43.5,29.8,22.6,60.1,41.6,55.0,6.8,17.5,46.1,27.5,59.0,69.3,10.6,66.0,65.0,77.1,38.4,37.0,61.3,55.2,null,57.6,54.1,55.2],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f ...

# %%
filter_df = datac_df.loc[datac_df["Demographics Response"]=="Higher"]
df = filter_df.groupby(["Country", "A3C"])["Value"].agg(["max"]).reset_index()
df.columns = ["Country", "A3C", "Max"]
show_on_map(df, "Max", "Violence against Women with Higher education - Country Max level of violence [%]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="60946041-e3c0-48a4-99ff-d67cbb306f4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60946041-e3c0-48a4-99ff-d67cbb306f4a")) {                    Plotly.newPlot(                        "60946041-e3c0-48a4-99ff-d67cbb306f4a",                        [{"autocolorscale":false,"colorbar":{"tickprefix":"%","title":{"text":"Violence %"}},"colorscale":[[0.0,"rgb(150,0,90)"],[0.125,"rgb(0,0,200)"],[0.25,"rgb(0,25,255)"],[0.375,"rgb(0,152,255)"],[0.5,"rgb(44,255,150)"],[0.625,"rgb(151,255,0)"],[0.75,"rgb(255,234,0)"],[0.875,"rgb(255,111,0)"],[1.0,"rgb(255,0,0)"]],"locations":["AFG","ALB","AGO","ARM","AZE","BGD","BEN","BOL","BFA","BDI","KHM","CMR","TCD","COL","COM","DOM","EGY","ERI","ETH","GAB","GMB","GHA","GTM","GIN","GUY","HTI","HND","IND","IDN","JOR","KEN","LSO","LBR","MDG","MWI","MDV","MLI","MAR","MOZ","MMR","NAM","NPL","NIC","NER","NGA","PAK","PER","PHL","RWA","STP","SEN","SLE","ZAF","TJK","TZA","TLS","TGO","TUR","TKM","UGA","UKR","YEM","ZMB","ZWE"],"marker":{"line":{"color":"darkgray","width":0.5}},"reversescale":false,"text":["Afghanistan","Albania","Angola","Armenia","Azerbaijan","Bangladesh","Benin","Bolivia","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Colombia","Comoros","Dominican Republic","Egypt","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guatemala","Guinea","Guyana","Haiti","Honduras","India","Indonesia","Jordan","Kenya","Lesotho","Liberia","Madagascar","Malawi","Maldives","Mali","Morocco","Mozambique","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Peru","Philippines","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","South Africa","Tajikistan","Tanzania","Timor-Leste","Togo","Turkey","Turkmenistan","Uganda","Ukraine","Yemen","Zambia","Zimbabwe"],"z":[61.1,5.4,7.0,14.4,52.5,13.4,4.7,5.7,15.0,22.2,18.5,23.6,60.1,1.7,23.7,0.9,13.3,32.1,26.1,24.1,28.2,4.2,1.8,46.8,8.6,3.5,1.3,33.8,25.5,27.2,23.1,17.1,18.5,20.0,4.5,18.1,55.6,20.8,8.6,34.9,12.8,17.4,2.7,17.6,16.9,17.4,1.8,7.5,11.3,13.4,9.7,32.3,5.8,51.7,12.5,74.6,8.8,3.7,30.3,21.7,7.9,22.9,15.0,13.7],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourc ...

# %% [markdown]
# # <a id='8'>Summary of findings</a>
#
#
# Some of the conclusions of the analysis are listed here:
#
# * The most exposed age group is the 15-24, with a median of 17.50 and max of 80.1, while the absolute max is for 25-34 age group;
#
# * Education level of girls and women is a very good predictor for violence against them: a higher education level will ensure a small median percent of 4.2%, while No education shows a 21.55% median and a 82% maximum violence percent.
#
# * Employment factor also counts, from Unemployed to Employed for kind the median is varying from 14.55% to 20.15%. The women that work tend to be more exposed to violence.
#
# * Marriage is slighly protecting if we look to the median, but married women are more exposed to higher level of violence. Widowed, divorced or separated have a smaller median than Married or living together group, as well as the max. But it might be also an age factor here.
#
# * Women from Urban areas are less exposed to violence than women from Rural areas, both the median and the max values being smaller in Urban vs. Rural areas.
#
# * Most exposed girls and women to extreme violence are from countries as Timor, Mali (subsaharian Africa), Chad, Eritreea, Afganistan and, surprisingly, Marroco. If the Marroco is a surprise, we should notice that the other countries are also either conflict zones or failes states, which is expected  to aggravate the life conditions of most exposed people.
#
# * In the highest violence countries, the worst condition (i.e. exposure to higher levels of violence) is that of women or girls without education.
